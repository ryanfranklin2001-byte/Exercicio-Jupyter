# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Análise de Vendas

# %%
df = pd.read_csv("../dados/vendas.csv")
df
# Out:
#          data   produto    categoria  valor
# 0  2024-01-01  Notebook  Eletrônicos   3500
# 1  2024-01-02     Mouse  Eletrônicos     80
# 2  2024-01-03   Cadeira       Móveis    600
# 3  2024-01-04   Teclado  Eletrônicos    120
# 4  2024-01-05      Mesa       Móveis    900

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   data       5 non-null      str
#  1   produto    5 non-null      str
#  2   categoria  5 non-null      str
#  3   valor      5 non-null      int64
# dtypes: int64(1), str(3)
# memory usage: 292.0 bytes

# %%
df["valor"].describe()
# Out:
# count       5.000000
# mean     1040.000000
# std      1417.109735
# min        80.000000
# 25%       120.000000
# 50%       600.000000
# 75%       900.000000
# max      3500.000000
# Name: valor, dtype: float64

# %%
vendas_categoria = df.groupby("categoria")["valor"].sum()
vendas_categoria
# Out:
# categoria
# Eletrônicos    3700
# Móveis         1500
# Name: valor, dtype: int64

# %%
plt.figure(figsize=(6, 4))
vendas_categoria.plot(kind="bar")
plt.title("Total de Vendas por Categoria")
plt.xlabel("Categoria")
plt.ylabel("Valor Total (R$)")
plt.show()

# %% [markdown]
# # 1.Qual categoria teve o maior total de vendas?
# Eletrônicos
# # 2.Qual foi o valor médio das vendas?
# 1040.000000
# # 3.Quantos produtos pertencem à categoria “Eletrônicos”?
# 3
# # 4.O gráfico confirma os valores da tabela?
# Sim
